# %%
import pandas as pd
import seaborn as sns
import allu_pandas

# %% [markdown]
# # Data
# Penduins: https://github.com/allisonhorst/penguins

# %%
df = pd.read_csv("../data/penguins.csv")

# %% [markdown]
# # Draw alluvial

# %%
allu_pandas.draw(
    df,
    ["species", "island", "sex"],
)

# %% [markdown]
# # Color the flow based on the groups in the middle

# %%
allu_pandas.draw(df, ["species", "island", "sex"], color_by = "island")
